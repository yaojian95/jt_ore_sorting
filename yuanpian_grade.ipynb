# %%
from dataloader import path2pixel, load_data
import cv2
import matplotlib.pyplot as plt
import numpy as np
import copy

# %%
from classifiers.r_method import RMethodClassifier

# %%
# image_low = cv2.flip(image[:, 0:int(image.shape[1]/2)], 1)
# image_high = cv2.flip(image[:, int(image.shape[1]/2):], 1)
# image_flipped = np.concatenate((image_low, image_high), axis=1)
# plt.imshow(image_flipped)

# cv2.imwrite('E:\\photoelectric_sorting\\data\\yoo_83_flipped.png', image_flipped)

# %%
cu_path = 'E:\\photoelectric_sorting\\data\\yoo_83_flipped.png'

# image = cv2.imread(cu_path, cv2.IMREAD_GRAYSCALE) 
m1 = path2pixel(cu_path, [0, -1, 400, 1000], max_len = 5, length=102, flip_hori=False,
               s_i = 1, th_val = 185, 
               reshape_factor=6, save_rock_image = False, direction = 'ublr', 
               save_rock_pixels=False, shrink_scale=0.5)

# %%
plt.figure(figsize = (6, 8))
plt.imshow(m1[3])

# %%
# Out:
# (685,)
